# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Student_Marks (1).csv')

# %%
data
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
x=data['time_study']
y=data['Marks']

# %%
plt.scatter(x,y)
plt.xlabel('time_study')
plt.ylabel('Marks')
# Out:
# Text(0, 0.5, 'Marks')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=23)

# %%
x_train
# Out:
# 74    6.954
# 84    1.982
# 52    0.771
# 50    6.703
# 46    3.797
# 34    4.083
# 99    6.335
# 88    1.803
# 79    0.805
# 0     4.508
# 14    2.908
# 30    3.864
# 95    3.561
# 38    6.533
# 22    2.051
# 13    4.274
# 56    7.641
# 32    0.932
# 35    7.543
# 44    1.954
# 10    7.353
# 2     3.133
# 93    6.471
# 96    0.301
# 58    6.198
# 70    3.736
# 43    1.557
# 1     0.096
# 65    2.142
# 36    2.966
# 15    4.260
# 92    5.027
# 59    7.468
# 33    6.594
# 19    3.977
# 57    7.649
# 62    3.606
# 41    2.754
# 48    5.635
# 21    6.126
# 86    4.067
# 64    0.130
# 69    3.948
# 75    0.803
# 66    5.473
# 49    3.913
# 12    4.218
# 45    2.061
# 6     6.063
# 51    4.130
# 25    1.407
# 90    4.182
# 39    7.775
# 91    2.730
# 76    6.379
# 31    1.923
# 54    7.591
# 73    1.629
# 40    0.140
# 83    3.197
# Name: time_study, dtype: float64

# %%
x_test
# Out:
# 26    0.508
# 80    7.957
# 82    7.410
# 68    1.395
# 77    5.985
# 37    7.283
# 3     7.909
# 55    2.913
# 20    4.733
# 17    6.080
# 72    4.633
# 24    3.635
# 71    2.518
# 87    1.033
# 89    6.376
# 29    1.299
# 9     6.173
# 67    0.550
# 42    3.591
# 94    3.919
# 85    6.201
# 28    0.156
# 8     4.410
# 11    0.423
# 63    4.869
# 4     7.811
# 53    6.049
# 5     3.211
# 81    2.262
# 98    0.309
# 97    7.163
# 23    4.875
# 7     3.413
# 60    0.376
# 27    4.378
# 78    7.451
# 18    7.711
# 61    2.438
# 47    4.779
# 16    5.719
# Name: time_study, dtype: float64

# %%
x_train=np.array(x_train).reshape(-1,1)
x_train
# Out:
# array([[6.954],
#        [1.982],
#        [0.771],
#        [6.703],
#        [3.797],
#        [4.083],
#        [6.335],
#        [1.803],
#        [0.805],
#        [4.508],
#        [2.908],
#        [3.864],
#        [3.561],
#        [6.533],
#        [2.051],
#        [4.274],
#        [7.641],
#        [0.932],
#        [7.543],
#        [1.954],
#        [7.353],
#        [3.133],
#        [6.471],
#        [0.301],
#        [6.198],
#        [3.736],
#        [1.557],
#        [0.096],
#        [2.142],
#        [2.966],
#        [4.26 ],
#        [5.027],
#        [7.468],
#        [6.594],
#        [3.977],
#        [7.649],
#        [3.606],
#        [2.754],
#        [5.635],
#        [6.126],
#        [4.067],
#        [0.13 ],
#        [3.948],
#        [0.803],
#        [5.473],
#        [3.913],
#        [4.218],
#        [2.061],
#        [6.063],
#        [4.13 ],
#        [1.407],
#        [4.182],
#        [7.775],
#        [2.73 ],
#        [6.379],
#        [1.923],
#        [7.591],
#        [1.629],
#        [0.14 ],
#        [3.197]])

# %%
x_test=np.array(x_test).reshape(-1,1)
x_test
# Out:
# array([[0.508],
#        [7.957],
#        [7.41 ],
#        [1.395],
#        [5.985],
#        [7.283],
#        [7.909],
#        [2.913],
#        [4.733],
#        [6.08 ],
#        [4.633],
#        [3.635],
#        [2.518],
#        [1.033],
#        [6.376],
#        [1.299],
#        [6.173],
#        [0.55 ],
#        [3.591],
#        [3.919],
#        [6.201],
#        [0.156],
#        [4.41 ],
#        [0.423],
#        [4.869],
#        [7.811],
#        [6.049],
#        [3.211],
#        [2.262],
#        [0.309],
#        [7.163],
#        [4.875],
#        [3.413],
#        [0.376],
#        [4.378],
#        [7.451],
#        [7.711],
#        [2.438],
#        [4.779],
#        [5.719]])

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_
c
# Out:
# 0.5358633613371033

# %%
m = lr.coef_
m
# Out:
# array([5.69985786])

# %%
y_pred_train = m*x_train + c
y_pred_train.flatten()
# Out:
# array([40.17267494, 11.83298165,  4.93045377, 38.74201061, 22.17822367,
#        23.80838301, 36.64446292, 10.81270709,  5.12424894, 26.23082261,
#        17.11105003, 22.56011414, 20.83305721, 37.77303478, 12.22627184,
#        24.89705587, 44.08847729,  5.84813089, 43.52989122, 11.67338562,
#        42.44691823, 18.39351805, 37.41964359,  2.25152058, 35.86358239,
#        21.83053234,  9.41054205,  1.08304972, 12.7449589 , 17.44164178,
#        24.81725786, 29.18904884, 43.10240188, 38.12072611, 23.20419808,
#        44.13407615, 21.08955081, 16.23327192, 32.65456242, 35.45319263,
#        23.71718529,  1.27684488, 23.0389022 ,  5.11284923, 31.73118544,
#        22.83940718, 24.57786383, 12.28327042, 35.09410158, 24.07627633,
#         8.55556337, 24.37266894, 44.85225824, 16.09647533, 36.89525667,
#        11.49669003, 43.8034844 ,  9.82093182,  1.33384346, 18.75830895])

# %%
Y_pred_train1 = lr.predict(x_train)
Y_pred_train1
# Out:
# array([40.17267494, 11.83298165,  4.93045377, 38.74201061, 22.17822367,
#        23.80838301, 36.64446292, 10.81270709,  5.12424894, 26.23082261,
#        17.11105003, 22.56011414, 20.83305721, 37.77303478, 12.22627184,
#        24.89705587, 44.08847729,  5.84813089, 43.52989122, 11.67338562,
#        42.44691823, 18.39351805, 37.41964359,  2.25152058, 35.86358239,
#        21.83053234,  9.41054205,  1.08304972, 12.7449589 , 17.44164178,
#        24.81725786, 29.18904884, 43.10240188, 38.12072611, 23.20419808,
#        44.13407615, 21.08955081, 16.23327192, 32.65456242, 35.45319263,
#        23.71718529,  1.27684488, 23.0389022 ,  5.11284923, 31.73118544,
#        22.83940718, 24.57786383, 12.28327042, 35.09410158, 24.07627633,
#         8.55556337, 24.37266894, 44.85225824, 16.09647533, 36.89525667,
#        11.49669003, 43.8034844 ,  9.82093182,  1.33384346, 18.75830895])

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,Y_pred_train1, color = 'red')
plt.xlabel('time_study')
plt.ylabel('Marks')
# Out:
# Text(0, 0.5, 'Marks')

# %%
Y_pred_test1 = lr.predict(x_test)
Y_pred_test1
# Out:
# array([ 3.43139116, 45.88963237, 42.77181012,  8.48716508, 34.64951267,
#        42.04792818, 45.6160392 , 17.13954932, 27.51329063, 35.19099917,
#        26.94330484, 21.25484669, 14.88810546,  6.42381653, 36.87815709,
#         7.93997872, 35.72108595,  3.67078519, 21.00405295, 22.87360633,
#        35.88068197,  1.42504119, 25.67223654,  2.94690324, 28.28847129,
#        45.05745313, 35.01430357, 18.83810696, 13.42894185,  2.29711944,
#        41.36394523, 28.32267044, 19.98947825,  2.67900992, 25.48984108,
#        43.0055043 , 44.48746734, 14.43211683, 27.77548409, 33.13335048])
