# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Earthquake Perception Dataset (1).csv")

# %%
data
# Out:
#       age     sex marital_status        residence               education  \
# 0    21.0    Male      Unmarried           Napoli  Upper Secondary School
# 1    21.0  Female      Unmarried           Napoli  Upper Secondary School
# 2    21.0  Female      Unmarried           Napoli  Upper Secondary School
# 3    23.0    Male      Unmarried           Quarto  Upper Secondary School
# 4    64.0  Female      Unmarried  Somma Vesuviana                  Degree
# ..    ...     ...            ...              ...                     ...
# 467  25.0    Male      Unmarried          Caserta                  Degree
# 468   NaN  Female      Unmarried          Cercola  Lower Secondary School
# 469  45.0  Female      Unmarried         Pozzuoli                  Degree
# 470  44.0  Female     Cohabiting         Pozzuoli     Postgraduate Degree
# 471  32.0  Female        Married        Gualtieri                  Degree
#
#          occupation out_of_region_employment family_members  \
# ...

# %%
data.head()
# Out:
#     age     sex marital_status        residence               education  \
# 0  21.0    Male      Unmarried           Napoli  Upper Secondary School
# 1  21.0  Female      Unmarried           Napoli  Upper Secondary School
# 2  21.0  Female      Unmarried           Napoli  Upper Secondary School
# 3  23.0    Male      Unmarried           Quarto  Upper Secondary School
# 4  64.0  Female      Unmarried  Somma Vesuviana                  Degree
#
#        occupation out_of_region_employment family_members family_disabilities  \
# 0         Student                       No              4                  No
# 1         Student                       No              5                  No
# 2  Student Worker                       No              5                  No
# 3         Student                       No              5                  No
# 4         Retired                       No              1                  No
#
# ...

# %%
data.tail()
# Out:
#       age     sex marital_status  residence               education  \
# 467  25.0    Male      Unmarried    Caserta                  Degree
# 468   NaN  Female      Unmarried    Cercola  Lower Secondary School
# 469  45.0  Female      Unmarried   Pozzuoli                  Degree
# 470  44.0  Female     Cohabiting   Pozzuoli     Postgraduate Degree
# 471  32.0  Female        Married  Gualtieri                  Degree
#
#         occupation out_of_region_employment family_members  \
# 467        Student                       No         Over 5
# 468        Student                       No              3
# 469       Employee                       No              1
# 470  Self-Employed                       No              4
# 471       Employee                      Yes              4
#
#     family_disabilities       house_floor  ... INGV_trust security  \
# 467                  No  0 (Ground Floor)  ...          3        3
# ...

# %%
data.shape
# Out:
# (472, 43)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472 entries, 0 to 471
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             456 non-null    float64
#  1   sex                             470 non-null    object
#  2   marital_status                  472 non-null    object
#  3   residence                       468 non-null    object
#  4   education                       472 non-null    object
#  5   occupation                      472 non-null    object
#  6   out_of_region_employment        472 non-null    object
#  7   family_members                  472 non-null    object
#  8   family_disabilities             464 non-null    object
#  9   house_floor                     472 non-null    object
#  10  earthquake80                    472 non-null    object
#  11  political_orientation           202 non-null    object
# ...

# %%
pd.isnull(data).sum()
# Out:
# age                                16
# sex                                 2
# marital_status                      0
# residence                           4
# education                           0
# occupation                          0
# out_of_region_employment            0
# family_members                      0
# family_disabilities                 8
# house_floor                         0
# earthquake80                        0
# political_orientation             270
# shocks                              0
# fear                                0
# anxiety                             0
# physiological_symptoms              0
# decision_timeliness                 0
# insomnia                            0
# seismic_concern                     0
# abroad                              0
# out_of_region                       0
# out_of_region_earthquake            0
# change_of_residence                 0
# change_of_residence_earthquake      0
# red_zone_frequency                  0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
sns.countplot(x=data['education'])
plt.xlabel("education")
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Upper Secondary School'),
#   Text(1, 0, 'Degree'),
#   Text(2, 0, 'Postgraduate Degree'),
#   Text(3, 0, 'Elementary School'),
#   Text(4, 0, 'Lower Secondary School')])

# %%
data=data.rename(columns={'sex':'gender'})

# %%
data
# Out:
#       age  gender marital_status        residence               education  \
# 0    21.0    Male      Unmarried           Napoli  Upper Secondary School
# 1    21.0  Female      Unmarried           Napoli  Upper Secondary School
# 2    21.0  Female      Unmarried           Napoli  Upper Secondary School
# 3    23.0    Male      Unmarried           Quarto  Upper Secondary School
# 4    64.0  Female      Unmarried  Somma Vesuviana                  Degree
# ..    ...     ...            ...              ...                     ...
# 467  25.0    Male      Unmarried          Caserta                  Degree
# 468   NaN  Female      Unmarried          Cercola  Lower Secondary School
# 469  45.0  Female      Unmarried         Pozzuoli                  Degree
# 470  44.0  Female     Cohabiting         Pozzuoli     Postgraduate Degree
# 471  32.0  Female        Married        Gualtieri                  Degree
#
#          occupation out_of_region_employment family_members  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472 entries, 0 to 471
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             456 non-null    float64
#  1   gender                          470 non-null    object
#  2   marital_status                  472 non-null    object
#  3   residence                       468 non-null    object
#  4   education                       472 non-null    object
#  5   occupation                      472 non-null    object
#  6   out_of_region_employment        472 non-null    object
#  7   family_members                  472 non-null    object
#  8   family_disabilities             464 non-null    object
#  9   house_floor                     472 non-null    object
#  10  earthquake80                    472 non-null    object
#  11  political_orientation           202 non-null    object
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
sns.countplot(x=data['gender'])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.pairplot(data)
plt.show()

# %%
plt.plot(data['age'])
plt.show()

# %%
sns.catplot(x="gender",y="age",data=data)

# %%
sns.catplot(x="age",y="gender",data=data,kind="bar")

# %%
sns.catplot(x="gender",y="age",data=data,hue="family_disabilities",col="marital_status",height=4)

# %%
plt.hist(data['age'],bins=20)
plt.title('Age')
plt.show()

# %%
sns.countplot(x=data['salary'])
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Up to €15000'),
#   Text(1, 0, 'Between €28000 and €50000'),
#   Text(2, 0, 'Between €15000 and €28000'),
#   Text(3, 0, 'Over €50000')])

# %%
sns.barplot(x="property_house",y="n_vehicles",data=data)
# Out:
# <Axes: xlabel='property_house', ylabel='n_vehicles'>
